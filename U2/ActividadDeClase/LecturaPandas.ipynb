# %%
# Importamos Librerías

import pandas  as pd
import sqlite3
import yfinance as yf

# %%
# Ejercicio 1
# Leer las tablas NBA_season1718_salary y Season_Stats dentro del archivo nba_salary.sqlite

sqlCon = sqlite3.connect('nba_salary.sqlite')
sqlCur = sqlCon.cursor()
sqlCur.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(sqlCur.fetchall())
# Out:
# [('NBA_season1718_salary',), ('Seasons_Stats',)]

# %%
df_all = pd.read_sql_query("SELECT * FROM sqlite_master WHERE type='table';",sqlCon)
df_all
# Out:
#     type                   name               tbl_name  rootpage  \
# 0  table  NBA_season1718_salary  NBA_season1718_salary         2
# 1  table          Seasons_Stats          Seasons_Stats         8
#
#                                                  sql
# 0  CREATE TABLE `NBA_season1718_salary` (\n  `X1`...
# 1  CREATE TABLE `Seasons_Stats` (\n  `X1` REAL,\n...

# %%
df_salary = pd.read_sql_query("SELECT * FROM 'NBA_season1718_salary'",sqlCon)
df_salary
# Out:
#         X1          Player   Tm  season17_18
# 0      1.0   Stephen Curry  GSW   34682550.0
# 1      2.0    LeBron James  CLE   33285709.0
# 2      3.0    Paul Millsap  DEN   31269231.0
# 3      4.0  Gordon Hayward  BOS   29727900.0
# 4      5.0   Blake Griffin  DET   29512900.0
# ..     ...             ...  ...          ...
# 568  569.0      Quinn Cook  NOP      25000.0
# 569  570.0   Chris Johnson  HOU      25000.0
# 570  571.0      Beno Udrih  DET      25000.0
# 571  572.0   Joel Bolomboy  MIL      22248.0
# 572  573.0    Jarell Eddie  CHI      17224.0
#
# [573 rows x 4 columns]

# %%
df_state = pd.read_sql_query("SELECT * FROM 'Seasons_Stats'",sqlCon)
df_state
# Out:
#             X1    Year             Player  Pos   Age   Tm     G   GS      MP  \
# 0          0.0  1950.0    Curly Armstrong  G-F  31.0  FTW  63.0  NaN     NaN
# 1          1.0  1950.0       Cliff Barker   SG  29.0  INO  49.0  NaN     NaN
# 2          2.0  1950.0      Leo Barnhorst   SF  25.0  CHS  67.0  NaN     NaN
# 3          3.0  1950.0         Ed Bartels    F  24.0  TOT  15.0  NaN     NaN
# 4          4.0  1950.0         Ed Bartels    F  24.0  DNN  13.0  NaN     NaN
# ...        ...     ...                ...  ...   ...  ...   ...  ...     ...
# 24686  24686.0  2017.0        Cody Zeller   PF  24.0  CHO  62.0  NaN  1725.0
# 24687  24687.0  2017.0       Tyler Zeller    C  27.0  BOS  51.0  NaN   525.0
# 24688  24688.0  2017.0  Stephen Zimmerman    C  20.0  ORL  19.0  0.0   108.0
# 24689  24689.0  2017.0        Paul Zipser   SF  22.0  CHI  44.0  NaN   843.0
# 24690  24690.0  2017.0        Ivica Zubac    C  19.0  LAL  38.0  NaN   609.0
#
# ...

# %%
# Ejercicio 2
# Leer el archivo JSON en la siguiente página Web: JSON file

df_json = pd.read_json('https://raw.githubusercontent.com/BindiChen/machine-learning/master/data-analysis/027-pandas-convert-json/data/simple.json')
df_json
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %%
# Ejercicio 3
# Utilizar la funcion Ticker de yfinance para extraer información relevante de la compañias PFE (Pfizer)

date = yf.Ticker('PFE')
date.info
date.calendar
date.analyst_price_targets
date.quarterly_income_stmt
date.history(period='1mo')
date.option_chain(date.options[0]).calls
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0   PFE250417C00012000 2025-04-15 13:43:53+00:00    12.0      10.44  8.20
# 1   PFE250417C00014000 2025-04-15 13:41:45+00:00    14.0       8.49  7.40
# 2   PFE250417C00015000 2025-04-16 19:58:19+00:00    15.0       7.06  6.05
# 3   PFE250417C00016000 2025-04-16 13:36:23+00:00    16.0       6.61  4.90
# 4   PFE250417C00017000 2025-04-16 13:32:00+00:00    17.0       5.49  4.05
# 5   PFE250417C00017500 2025-04-16 13:46:33+00:00    17.5       4.95  4.50
# 6   PFE250417C00018000 2025-04-15 16:38:10+00:00    18.0       4.56  4.00
# 7   PFE250417C00019000 2025-04-15 18:30:15+00:00    19.0       3.46  2.99
# 8   PFE250417C00019500 2025-04-16 17:34:49+00:00    19.5       2.71  2.14
# 9   PFE250417C00020000 2025-04-16 18:50:17+00:00    20.0       2.12  1.97
# 10  PFE250417C00020500 2025-04-15 18:52:14+00:00    20.5       1.84  1.53
# 11  PFE250417C00021000 2025-04-16 19:02:22+00:00    21.0       1.03  0.84
# ...
