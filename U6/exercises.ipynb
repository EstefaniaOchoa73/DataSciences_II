# %%
# Librerias
import pandas as pd

# %%
# 1- PREPARAMOS LOS DATOS.
df_seguros = pd.read_csv('Dataset_de_Seguros_Actualizado.csv',sep=',')
df_seguros
# Out:
#      ID_Cliente  Edad  Prima_Seguro Tipo_Seguro Genero  \
# 0             1    56       4737.44        Auto      M
# 1             2    69      13342.43        Vida      M
# 2             3    46       5329.27  Tecnología      F
# 3             4    32      11128.12       Viaje      M
# 4             5    60      12809.77        Auto      M
# ..          ...   ...           ...         ...    ...
# 995         996    37      16674.24        Auto      M
# 996         997    41      13030.21        Auto      F
# 997         998    22      13645.09        Auto      M
# 998         999    51      11299.78       Viaje      M
# 999        1000    23      15102.46        Auto      M
#
#      Antiguedad_Cliente_Anios  Reclamos_Anuales     Provincia  \
# 0                           0                 0      Misiones
# 1                           6                 0       Mendoza
# 2                          10                 0    Entre Ríos
# ...

# %%
df_seguros2 = pd.read_csv('Dataset_de_seguros.csv',sep=',')
df_seguros2
# Out:
#       ID_Cliente  Edad  Prima_Seguro Tipo_Seguro Genero  \
# 0           1002    63      24068.44       Salud      M
# 1           1003    35       7457.25       Salud      F
# 2           1004    26      10430.74        Vida      F
# 3           1005    71       8365.58       Salud      F
# 4           1006    58      10823.10        Auto      F
# ...          ...   ...           ...         ...    ...
# 1495        2497    72      13368.43       Salud      F
# 1496        2498    47       7669.59       Hogar      F
# 1497        2499    51       9686.74       Hogar      F
# 1498        2500    56      11828.36       Salud      F
# 1499        2501    26      12504.87        Vida      F
#
#       Antiguedad_Cliente_Anios  Reclamos_Anuales     Provincia  \
# 0                            8                 2    Corrientes
# 1                            3                 1      Santa Fe
# 2                            4                 4         Salta
# ...
