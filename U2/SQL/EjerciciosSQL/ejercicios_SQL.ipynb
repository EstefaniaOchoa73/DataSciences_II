# %%
# Importar librerías

import pandas as pd
import sqlite3

# %%
# Cargar Base de Datos

conn = sqlite3.connect('BASE DE DATOS/northwind.db')
conn

# %%
# Consulto cuales son los nombres de las tablas.

sqlCur = conn.cursor()
sqlCur.execute('SELECT name FROM sqlite_master WHERE type="table"')
sqlCur.fetchall()
# Out:
# [('Categories',),
#  ('sqlite_sequence',),
#  ('CustomerCustomerDemo',),
#  ('CustomerDemographics',),
#  ('Customers',),
#  ('Employees',),
#  ('EmployeeTerritories',),
#  ('Order Details',),
#  ('Orders',),
#  ('Products',),
#  ('Regions',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('Territories',)]

# %%
# Leemos con Pandas las tablas disponibles

df_SQL = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';",conn)
df_SQL
# Out:
#                     name
# 0             Categories
# 1        sqlite_sequence
# 2   CustomerCustomerDemo
# 3   CustomerDemographics
# 4              Customers
# 5              Employees
# 6    EmployeeTerritories
# 7          Order Details
# 8                 Orders
# 9               Products
# 10               Regions
# 11              Shippers
# 12             Suppliers
# 13           Territories

# %% [markdown]
# 🔵 20 Ejercicios SQL - Nivel Inicial (Base: Northwind)

# %%
# 1- Mostrar todos los clientes.

df_Customers = pd.read_sql_query('SELECT CustomerID, ContactName, Address FROM Customers', conn)
df_Customers
# Out:
#    CustomerID              ContactName                        Address
# 0       ALFKI             Maria Anders                  Obere Str. 57
# 1       ANATR             Ana Trujillo  Avda. de la Constitución 2222
# 2       ANTON           Antonio Moreno                Mataderos  2312
# 3       AROUT             Thomas Hardy                120 Hanover Sq.
# 4       BERGS       Christina Berglund                Berguvsvägen  8
# ..        ...                      ...                            ...
# 88      WARTH         Pirkko Koskitalo                    Torikatu 38
# 89      WELLI            Paula Parente             Rua do Mercado, 12
# 90      WHITC           Karl Jablonski    305 - 14th Ave. S. Suite 3B
# 91      WILMK          Matti Karttunen                  Keskuskatu 45
# 92      WOLZA  Zbyszek Piestrzeniewicz                ul. Filtrowa 68
#
# [93 rows x 3 columns]

# %%
# 2-Listar los nombres de los productos.

df_products = pd.read_sql_query('SELECT ProductName FROM Products',conn)
df_products
# Out:
#                         ProductName
# 0                              Chai
# 1                             Chang
# 2                     Aniseed Syrup
# 3      Chef Anton's Cajun Seasoning
# 4            Chef Anton's Gumbo Mix
# ..                              ...
# 72                       Röd Kaviar
# 73                    Longlife Tofu
# 74             Rhönbräu Klosterbier
# 75                     Lakkalikööri
# 76  Original Frankfurter grüne Soße
#
# [77 rows x 1 columns]

# %%
# 3-Mostrar los primeros 10 empleados.

# Otra forma de cumplir con la consigna es:
# df_employees = pd.read_sql_query('SELECT * FROM Employees',conn)
# df_employees.head(10)

df_employees = pd.read_sql_query('SELECT * FROM Employees LIMIT 10',conn)
df_employees
# Out:
#    EmployeeID   LastName FirstName                     Title TitleOfCourtesy  \
# 0           1    Davolio     Nancy      Sales Representative             Ms.
# 1           2     Fuller    Andrew     Vice President, Sales             Dr.
# 2           3  Leverling     Janet      Sales Representative             Ms.
# 3           4    Peacock  Margaret      Sales Representative            Mrs.
# 4           5   Buchanan    Steven             Sales Manager             Mr.
# 5           6     Suyama   Michael      Sales Representative             Mr.
# 6           7       King    Robert      Sales Representative             Mr.
# 7           8   Callahan     Laura  Inside Sales Coordinator             Ms.
# 8           9  Dodsworth      Anne      Sales Representative             Ms.
#
#     BirthDate    HireDate                         Address      City  \
# 0  1968-12-08  2012-05-01       507 - 20th Ave. E.Apt. 2A   Seattle
# ...

# %%
# 4-Listar las órdenes realizadas por clientes de Alemania.

df_Orders = pd.read_sql_query('SELECT Orders.OrderID, Orders.ShipName FROM Orders ' \
                              'INNER JOIN Customers ON Orders.CustomerID = Customers.CustomerID ' \
                              'WHERE Customers.Country = "Germany"',conn)
df_Orders
# Out:
#       OrderID                    ShipName
# 0       10249          Toms Spezialitäten
# 1       10260          Ottilies Käseladen
# 2       10267              Frankenversand
# 3       10273                  QUICK-Stop
# 4       10277      Morgenstern Gesundkost
# ...       ...                         ...
# 1890    26474       Split Rail Beer & Ale
# 1891    26490  Cactus Comidas para llevar
# 1892    26496               B-s Beverages
# 1893    26498        White Clover Markets
# 1894    26499      Princesa Isabel Vinhos
#
# [1895 rows x 2 columns]

# %%
# 5-Obtener todos los productos con precio mayor a 20.
df_products20 = pd.read_sql_query('SELECT Products.* FROM Products WHERE Products.UnitPrice > 20',conn)
df_products20
# Out:
#     ProductID                       ProductName  SupplierID  CategoryID  \
# 0           4      Chef Anton's Cajun Seasoning           2           2
# 1           5            Chef Anton's Gumbo Mix           2           2
# 2           6      Grandma's Boysenberry Spread           3           2
# 3           7   Uncle Bob's Organic Dried Pears           3           7
# 4           8        Northwoods Cranberry Sauce           3           2
# 5           9                   Mishi Kobe Niku           4           6
# 6          10                             Ikura           4           8
# 7          11                    Queso Cabrales           5           4
# 8          12         Queso Manchego La Pastora           5           4
# 9          14                              Tofu           6           7
# 10         17                      Alice Mutton           7           6
# 11         18                  Carnarvon Tigers           7           8
# ...

# %%
# 6-Mostrar los nombres y cargos de los empleados.

df_employees = pd.read_sql_query('SELECT Employees.LastName, Employees.FirstName, Employees.Title ' \
                                 'FROM Employees',conn)
df_employees
# Out:
#     LastName FirstName                     Title
# 0    Davolio     Nancy      Sales Representative
# 1     Fuller    Andrew     Vice President, Sales
# 2  Leverling     Janet      Sales Representative
# 3    Peacock  Margaret      Sales Representative
# 4   Buchanan    Steven             Sales Manager
# 5     Suyama   Michael      Sales Representative
# 6       King    Robert      Sales Representative
# 7   Callahan     Laura  Inside Sales Coordinator
# 8  Dodsworth      Anne      Sales Representative

# %%
# 7-Listar los nombres de los clientes y su país.

df_clients = pd.read_sql_query('SELECT ContactName, Country FROM Customers',conn)
df_clients
# Out:
#                 ContactName  Country
# 0              Maria Anders  Germany
# 1              Ana Trujillo   Mexico
# 2            Antonio Moreno   Mexico
# 3              Thomas Hardy       UK
# 4        Christina Berglund   Sweden
# ..                      ...      ...
# 88         Pirkko Koskitalo  Finland
# 89            Paula Parente   Brazil
# 90           Karl Jablonski      USA
# 91          Matti Karttunen  Finland
# 92  Zbyszek Piestrzeniewicz   Poland
#
# [93 rows x 2 columns]

# %%
# 8-Contar cuántos productos hay en total.

df_productsCount = pd.read_sql_query('SELECT COUNT(ProductID) FROM Products',conn)
df_productsCount
# Out:
#    COUNT(ProductID)
# 0                77

# %%
# 9-Mostrar los productos ordenados por precio de mayor a menor.

df_productsOrder = pd.read_sql_query('SELECT ProductName, UnitPrice FROM Products ORDER BY UnitPrice DESC',conn)
df_productsOrder
# Out:
#                 ProductName  UnitPrice
# 0             Côte de Blaye     263.50
# 1   Thüringer Rostbratwurst     123.79
# 2           Mishi Kobe Niku      97.00
# 3    Sir Rodney's Marmalade      81.00
# 4          Carnarvon Tigers      62.50
# ..                      ...        ...
# 72                Tourtière       7.45
# 73                 Filo Mix       7.00
# 74                    Konbu       6.00
# 75       Guaraná Fantástica       4.50
# 76                  Geitost       2.50
#
# [77 rows x 2 columns]

# %%
# 10-Mostrar las categorías de productos.

df_category = pd.read_sql_query('SELECT * FROM Categories',conn)
df_category
# Out:
#    CategoryID    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           5  Grains/Cereals
# 5           6    Meat/Poultry
# 6           7         Produce
# 7           8         Seafood
#
#                                          Description  \
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal
# 5                                     Prepared meats
# 6                          Dried fruit and bean curd
# 7                                   Seaweed and fish
#
#                                              Picture
# 0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00...
# 1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00...
# ...

# %%
# 11-Listar los productos y el nombre de su categoría.
# Dos formas posibles.

df_prodCat = pd.read_sql_query('SELECT Products.ProductName, Categories.CategoryName ' \
                              'FROM Products ' \
                               'INNER JOIN  Categories ' \
                               'ON Products.CategoryID == Categories.CategoryID',conn)

df_prodCat = pd.read_sql_query('SELECT Products.ProductName, Categories.CategoryName ' \
                               'FROM Products, Categories ' \
                               'WHERE Products.CategoryID = Categories.CategoryID',conn)
df_prodCat
# Out:
#                         ProductName CategoryName
# 0                              Chai    Beverages
# 1                             Chang    Beverages
# 2                     Aniseed Syrup   Condiments
# 3      Chef Anton's Cajun Seasoning   Condiments
# 4            Chef Anton's Gumbo Mix   Condiments
# ..                              ...          ...
# 72                       Röd Kaviar      Seafood
# 73                    Longlife Tofu      Produce
# 74             Rhönbräu Klosterbier    Beverages
# 75                     Lakkalikööri    Beverages
# 76  Original Frankfurter grüne Soße   Condiments
#
# [77 rows x 2 columns]

# %%
# 12-Mostrar los productos cuyo nombre comience con la letra 'C'.

df_productC = pd.read_sql_query('SELECT Products.*' \
                                'FROM Products WHERE ProductName LIKE "C%"',conn)

df_productC
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                          Chai           1           1
# 1          2                         Chang           1           1
# 2          4  Chef Anton's Cajun Seasoning           2           2
# 3          5        Chef Anton's Gumbo Mix           2           2
# 4         18              Carnarvon Tigers           7           8
# 5         38                 Côte de Blaye          18           1
# 6         39              Chartreuse verte          18           1
# 7         48                     Chocolade          22           3
# 8         60             Camembert Pierrot          28           4
#
#       QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0  10 boxes x 20 bags      18.00            39             0            10
# 1  24 - 12 oz bottles      19.00            17            40            25
# ...

# %%
# 13-Ver los proveedores de productos.

df_vendors = pd.read_sql_query('SELECT Products.ProductName, Suppliers.CompanyName, Suppliers.ContactName, Suppliers.ContactTitle, Suppliers.Address ' \
                               'FROM Suppliers ' \
                               'INNER JOIN Products ' \
                               'ON Suppliers.SupplierID = Products.SupplierID',conn)
df_vendors
# Out:
#                         ProductName                        CompanyName  \
# 0                              Chai                     Exotic Liquids
# 1                             Chang                     Exotic Liquids
# 2                     Aniseed Syrup                     Exotic Liquids
# 3      Chef Anton's Cajun Seasoning         New Orleans Cajun Delights
# 4            Chef Anton's Gumbo Mix         New Orleans Cajun Delights
# ..                              ...                                ...
# 72                       Röd Kaviar                  Svensk Sjöföda AB
# 73                    Longlife Tofu                      Tokyo Traders
# 74             Rhönbräu Klosterbier  Plutzer Lebensmittelgroßmärkte AG
# 75                     Lakkalikööri                          Karkki Oy
# 76  Original Frankfurter grüne Soße  Plutzer Lebensmittelgroßmärkte AG
#
#          ContactName                  ContactTitle                     Address
# ...

# %%
# 14-Ver todos los pedidos hechos en el año 1997.

df_orders = pd.read_sql_query('SELECT OrderID FROM Orders WHERE OrderDate LIKE "1997%"',conn)
#df_orders = pd.read_sql_query('SELECT * FROM Orders',conn)
df_orders
# Out:
# Empty DataFrame
# Columns: [OrderID]
# Index: []

# %%
# 15-Mostrar los países únicos de los clientes.

# SELECT DISTINCT retorna los valores distintos o diferentes.

df_countryClients = pd.read_sql_query('SELECT DISTINCT Country FROM Customers',conn)
df_countryClients
# Out:
#         Country
# 0       Germany
# 1        Mexico
# 2            UK
# 3        Sweden
# 4        France
# 5         Spain
# 6        Canada
# 7     Argentina
# 8   Switzerland
# 9        Brazil
# 10      Austria
# 11        Italy
# 12     Portugal
# 13          USA
# 14    Venezuela
# 15      Ireland
# 16      Belgium
# 17       Norway
# 18      Denmark
# 19         None
# 20      Finland
# 21       Poland

# %%
# 16-Ver la cantidad de productos por categoría.
df_categoryProd = pd.read_sql_query('SELECT ProductName, COUNT(ProductID)' \
                                    'FROM Products ' \
                                    'INNER JOIN Categories ON Products.CategoryID = Categories.CategoryID',conn)
df_categoryProd
# Out:
#   ProductName  COUNT(ProductID)
# 0        Chai                77

# %%
# 17-Mostrar las órdenes junto con el nombre del empleado que las gestionó.
df_orders = pd.read_sql_query('SELECT Orders.OrderID, Employees.FirstName, Employees.LastName ' \
                              'FROM Orders ' \
                              'INNER JOIN Employees ' \
                              'ON Orders.EmployeeID = Employees.EmployeeID ',conn)
df_orders
# Out:
#        OrderID FirstName   LastName
# 0        10248    Steven   Buchanan
# 1        10249   Michael     Suyama
# 2        10250  Margaret    Peacock
# 3        10251     Janet  Leverling
# 4        10252  Margaret    Peacock
# ...        ...       ...        ...
# 16277    26525   Michael     Suyama
# 16278    26526      Anne  Dodsworth
# 16279    26527  Margaret    Peacock
# 16280    26528      Anne  Dodsworth
# 16281    26529   Michael     Suyama
#
# [16282 rows x 3 columns]

# %%
# 18-Ver qué productos tienen stock

df_stock = pd.read_sql_query('SELECT Products.* FROM Products WHERE UnitsInStock != 0',conn)
df_stock
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID  \
# 0           1                             Chai           1           1
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           6     Grandma's Boysenberry Spread           3           2
# ..        ...                              ...         ...         ...
# 67         73                       Röd Kaviar          17           8
# 68         74                    Longlife Tofu           4           7
# 69         75             Rhönbräu Klosterbier          12           1
# 70         76                     Lakkalikööri          23           1
# 71         77  Original Frankfurter grüne Soße          12           2
#
#         QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# ...

# %%
# 19-Calcular el precio promedio de los productos.

df_priceAvg = pd.read_sql_query('SELECT ProductName AS ProductName, AVG(QuantityPerUnit) AS PrecioPromedio FROM Products',conn)
df_priceAvg
# Out:
#   ProductName  PrecioPromedio
# 0        Chai       43.909091

# %%
# 20-Mostrar los 5 productos más caros.

df_priceMax = pd.read_sql_query('SELECT TOP ProductName, UnitPrice FROM Products ORDER BY UnitPrice',conn)
df_priceMax
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: no such column: TOP
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[115], line 3
#       1 # 20-Mostrar los 5 productos más caros.
# ----> 3 df_priceMax = pd.read_sql_query('SELECT TOP ProductName, UnitPrice FROM Products ORDER BY UnitPrice',conn)
#       4 df_priceMax
#
# ...
